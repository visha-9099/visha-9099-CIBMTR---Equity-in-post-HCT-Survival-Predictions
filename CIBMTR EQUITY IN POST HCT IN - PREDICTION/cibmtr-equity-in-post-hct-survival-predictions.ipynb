# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
pd.options.display.max_columns=None
import warnings

# %%
train = pd.read_csv('/kaggle/input/equity-post-HCT-survival-predictions/train.csv')
train.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#    ID                       dri_score psych_disturb    cyto_score diabetes  \
# 0   0  N/A - non-malignant indication            No           NaN       No
# 1   1                    Intermediate            No  Intermediate       No
# 2   2  N/A - non-malignant indication            No           NaN       No
# 3   3                            High            No  Intermediate       No
# 4   4                            High            No           NaN       No
#
#    hla_match_c_high  hla_high_res_8          tbi_status arrhythmia  \
# 0               NaN             NaN              No TBI         No
# 1               2.0             8.0  TBI +- Other, >cGy         No
# 2               2.0             8.0              No TBI         No
# 3               2.0             8.0              No TBI         No
# 4               2.0             8.0              No TBI         No
#
#    hla_low_res_6        graft_type vent_hist renal_issue pulm_severe  \
# 0            6.0       Bone marrow        No          No          No
# 1            6.0  Peripheral blood        No          No          No
# 2            6.0       Bone marrow        No          No          No
# 3            6.0       Bone marrow        No          No          No
# 4            6.0  Peripheral blood        No          No          No
#
#   prim_disease_hct  hla_high_res_6 cmv_status  hla_high_res_10  \
# 0              IEA             6.0        +/+              NaN
# 1              AML             6.0        +/+             10.0
# 2              HIS             6.0        +/+             10.0
# 3              ALL             6.0        +/+             10.0
# 4              MPN             6.0        +/+             10.0
#
#    hla_match_dqb1_high tce_imm_match  hla_nmdp_6  hla_match_c_low rituximab  \
# 0                  2.0           NaN         6.0              2.0        No
# 1                  2.0           P/P         6.0              2.0        No
# 2                  2.0           P/P         6.0              2.0        No
# 3                  2.0           P/P         6.0              2.0        No
# 4                  2.0           NaN         5.0              2.0        No
#
#    hla_match_drb1_low  hla_match_dqb1_low prod_type cyto_score_detail  \
# 0                 2.0                 2.0        BM               NaN
# 1                 2.0                 2.0        PB      Intermediate
# 2                 2.0                 2.0        BM               NaN
# 3                 2.0                 2.0        BM      Intermediate
# 4                 2.0                 2.0        PB               NaN
#
#   conditioning_intensity               ethnicity  year_hct obesity   mrd_hct  \
# 0                    NaN  Not Hispanic or Latino      2016      No       NaN
# 1                    MAC  Not Hispanic or Latino      2008      No  Positive
# 2                    NaN  Not Hispanic or Latino      2019      No       NaN
# 3                    MAC  Not Hispanic or Latino      2009      No  Positive
# 4                    MAC      Hispanic or Latino      2018      No       NaN
#
#   in_vivo_tcd   tce_match  hla_match_a_high hepatic_severe  donor_age  \
# 0         Yes         NaN               2.0             No        NaN
# 1          No  Permissive               2.0             No      72.29
# 2         Yes         NaN               2.0             No        NaN
# 3          No  Permissive               2.0             No      29.23
# 4         Yes         NaN               2.0             No      56.81
#
#   prior_tumor  hla_match_b_low peptic_ulcer  age_at_hct  hla_match_a_low  \
# 0          No              2.0           No       9.942              2.0
# 1          No              2.0           No      43.705              2.0
# 2          No              2.0           No      33.997              2.0
# 3          No              2.0           No      43.245              2.0
# 4          No              2.0           No      29.740              2.0
#
#                gvhd_proph rheum_issue sex_match  hla_match_b_high  \
# 0                 FKalone          No       M-F               2.0
# 1  Other GVHD Prophylaxis          No       F-F               2.0
# 2  Cyclophosphamide alone          No       F-M               2.0
# 3       FK+ MMF +- others          No       M-M               2.0
# 4     TDEPLETION +- other          No       M-F               2.0
#
#                          race_group  comorbidity_score  karnofsky_score  \
# 0                More than one race                0.0             90.0
# 1                             Asian                3.0             90.0
# 2                More than one race                0.0             90.0
# 3                             White                0.0             90.0
# 4  American Indian or Alaska Native                1.0             90.0
#
#   hepatic_mild          tce_div_match donor_related      melphalan_dose  \
# 0           No                    NaN     Unrelated  N/A, Mel not given
# 1           No  Permissive mismatched       Related  N/A, Mel not given
# 2           No  Permissive mismatched       Related  N/A, Mel not given
# 3          Yes  Permissive mismatched     Unrelated  N/A, Mel not given
# 4           No  Permissive mismatched       Related                 MEL
#
#    hla_low_res_8 cardiac  hla_match_drb1_high pulm_moderate  hla_low_res_10  \
# 0            8.0      No                  2.0            No            10.0
# 1            8.0      No                  2.0           Yes            10.0
# 2            8.0      No                  2.0            No            10.0
# 3            8.0      No                  2.0            No            10.0
# 4            8.0      No                  2.0            No            10.0
#
#    efs  efs_time
# 0  0.0    42.356
# 1  1.0     4.672
# 2  0.0    19.793
# 3  0.0   102.349
# 4  0.0    16.223

# %%
test =pd.read_csv('/kaggle/input/equity-post-HCT-survival-predictions/test.csv')
test.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#       ID                       dri_score psych_disturb    cyto_score diabetes  \
# 0  28800  N/A - non-malignant indication            No           NaN       No
# 1  28801                    Intermediate            No  Intermediate       No
# 2  28802  N/A - non-malignant indication            No           NaN       No
#
#    hla_match_c_high  hla_high_res_8          tbi_status arrhythmia  \
# 0               NaN             NaN              No TBI         No
# 1               2.0             8.0  TBI +- Other, >cGy         No
# 2               2.0             8.0              No TBI         No
#
#    hla_low_res_6        graft_type vent_hist renal_issue pulm_severe  \
# 0            6.0       Bone marrow        No          No          No
# 1            6.0  Peripheral blood        No          No          No
# 2            6.0       Bone marrow        No          No          No
#
#   prim_disease_hct  hla_high_res_6 cmv_status  hla_high_res_10  \
# 0              IEA             6.0        +/+              NaN
# 1              AML             6.0        +/+             10.0
# 2              HIS             6.0        +/+             10.0
#
#    hla_match_dqb1_high tce_imm_match  hla_nmdp_6  hla_match_c_low rituximab  \
# 0                  2.0           NaN         6.0              2.0        No
# 1                  2.0           P/P         6.0              2.0        No
# 2                  2.0           P/P         6.0              2.0        No
#
#    hla_match_drb1_low  hla_match_dqb1_low prod_type cyto_score_detail  \
# 0                 2.0                 2.0        BM               NaN
# 1                 2.0                 2.0        PB      Intermediate
# 2                 2.0                 2.0        BM               NaN
#
#   conditioning_intensity               ethnicity  year_hct obesity   mrd_hct  \
# 0                    NaN  Not Hispanic or Latino      2016      No       NaN
# 1                    MAC  Not Hispanic or Latino      2008      No  Positive
# 2                    NaN  Not Hispanic or Latino      2019      No       NaN
#
#   in_vivo_tcd   tce_match  hla_match_a_high hepatic_severe  donor_age  \
# 0         Yes         NaN               2.0             No        NaN
# 1          No  Permissive               2.0             No      72.29
# 2         Yes         NaN               2.0             No        NaN
#
#   prior_tumor  hla_match_b_low peptic_ulcer  age_at_hct  hla_match_a_low  \
# 0          No              2.0           No       9.942              2.0
# 1          No              2.0           No      43.705              2.0
# 2          No              2.0           No      33.997              2.0
#
#                gvhd_proph rheum_issue sex_match  hla_match_b_high  \
# 0                 FKalone          No       M-F               2.0
# 1  Other GVHD Prophylaxis          No       F-F               2.0
# 2  Cyclophosphamide alone          No       F-M               2.0
#
#            race_group  comorbidity_score  karnofsky_score hepatic_mild  \
# 0  More than one race                0.0             90.0           No
# 1               Asian                3.0             90.0           No
# 2  More than one race                0.0             90.0           No
#
#            tce_div_match donor_related      melphalan_dose  hla_low_res_8  \
# 0                    NaN     Unrelated  N/A, Mel not given            8.0
# 1  Permissive mismatched       Related  N/A, Mel not given            8.0
# 2  Permissive mismatched       Related  N/A, Mel not given            8.0
#
#   cardiac  hla_match_drb1_high pulm_moderate  hla_low_res_10
# 0      No                  2.0            No            10.0
# 1      No                  2.0           Yes            10.0
# 2      No                  2.0            No            10.0

# %%
combined = pd.concat([train,test]) 
combined.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#    ID                       dri_score psych_disturb    cyto_score diabetes  \
# 0   0  N/A - non-malignant indication            No           NaN       No
# 1   1                    Intermediate            No  Intermediate       No
# 2   2  N/A - non-malignant indication            No           NaN       No
# 3   3                            High            No  Intermediate       No
# 4   4                            High            No           NaN       No
#
#    hla_match_c_high  hla_high_res_8          tbi_status arrhythmia  \
# 0               NaN             NaN              No TBI         No
# 1               2.0             8.0  TBI +- Other, >cGy         No
# 2               2.0             8.0              No TBI         No
# 3               2.0             8.0              No TBI         No
# 4               2.0             8.0              No TBI         No
#
#    hla_low_res_6        graft_type vent_hist renal_issue pulm_severe  \
# 0            6.0       Bone marrow        No          No          No
# 1            6.0  Peripheral blood        No          No          No
# 2            6.0       Bone marrow        No          No          No
# 3            6.0       Bone marrow        No          No          No
# 4            6.0  Peripheral blood        No          No          No
#
#   prim_disease_hct  hla_high_res_6 cmv_status  hla_high_res_10  \
# 0              IEA             6.0        +/+              NaN
# 1              AML             6.0        +/+             10.0
# 2              HIS             6.0        +/+             10.0
# 3              ALL             6.0        +/+             10.0
# 4              MPN             6.0        +/+             10.0
#
#    hla_match_dqb1_high tce_imm_match  hla_nmdp_6  hla_match_c_low rituximab  \
# 0                  2.0           NaN         6.0              2.0        No
# 1                  2.0           P/P         6.0              2.0        No
# 2                  2.0           P/P         6.0              2.0        No
# 3                  2.0           P/P         6.0              2.0        No
# 4                  2.0           NaN         5.0              2.0        No
#
#    hla_match_drb1_low  hla_match_dqb1_low prod_type cyto_score_detail  \
# 0                 2.0                 2.0        BM               NaN
# 1                 2.0                 2.0        PB      Intermediate
# 2                 2.0                 2.0        BM               NaN
# 3                 2.0                 2.0        BM      Intermediate
# 4                 2.0                 2.0        PB               NaN
#
#   conditioning_intensity               ethnicity  year_hct obesity   mrd_hct  \
# 0                    NaN  Not Hispanic or Latino      2016      No       NaN
# 1                    MAC  Not Hispanic or Latino      2008      No  Positive
# 2                    NaN  Not Hispanic or Latino      2019      No       NaN
# 3                    MAC  Not Hispanic or Latino      2009      No  Positive
# 4                    MAC      Hispanic or Latino      2018      No       NaN
#
#   in_vivo_tcd   tce_match  hla_match_a_high hepatic_severe  donor_age  \
# 0         Yes         NaN               2.0             No        NaN
# 1          No  Permissive               2.0             No      72.29
# 2         Yes         NaN               2.0             No        NaN
# 3          No  Permissive               2.0             No      29.23
# 4         Yes         NaN               2.0             No      56.81
#
#   prior_tumor  hla_match_b_low peptic_ulcer  age_at_hct  hla_match_a_low  \
# 0          No              2.0           No       9.942              2.0
# 1          No              2.0           No      43.705              2.0
# 2          No              2.0           No      33.997              2.0
# 3          No              2.0           No      43.245              2.0
# 4          No              2.0           No      29.740              2.0
#
#                gvhd_proph rheum_issue sex_match  hla_match_b_high  \
# 0                 FKalone          No       M-F               2.0
# 1  Other GVHD Prophylaxis          No       F-F               2.0
# 2  Cyclophosphamide alone          No       F-M               2.0
# 3       FK+ MMF +- others          No       M-M               2.0
# 4     TDEPLETION +- other          No       M-F               2.0
#
#                          race_group  comorbidity_score  karnofsky_score  \
# 0                More than one race                0.0             90.0
# 1                             Asian                3.0             90.0
# 2                More than one race                0.0             90.0
# 3                             White                0.0             90.0
# 4  American Indian or Alaska Native                1.0             90.0
#
#   hepatic_mild          tce_div_match donor_related      melphalan_dose  \
# 0           No                    NaN     Unrelated  N/A, Mel not given
# 1           No  Permissive mismatched       Related  N/A, Mel not given
# 2           No  Permissive mismatched       Related  N/A, Mel not given
# 3          Yes  Permissive mismatched     Unrelated  N/A, Mel not given
# 4           No  Permissive mismatched       Related                 MEL
#
#    hla_low_res_8 cardiac  hla_match_drb1_high pulm_moderate  hla_low_res_10  \
# 0            8.0      No                  2.0            No            10.0
# 1            8.0      No                  2.0           Yes            10.0
# 2            8.0      No                  2.0            No            10.0
# 3            8.0      No                  2.0            No            10.0
# 4            8.0      No                  2.0            No            10.0
#
#    efs  efs_time
# 0  0.0    42.356
# 1  1.0     4.672
# 2  0.0    19.793
# 3  0.0   102.349
# 4  0.0    16.223

# %%
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28803 entries, 0 to 2
# Data columns (total 60 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      28803 non-null  int64
#  1   dri_score               28649 non-null  object
#  2   psych_disturb           26741 non-null  object
#  3   cyto_score              20733 non-null  object
#  4   diabetes                26684 non-null  object
#  5   hla_match_c_high        24182 non-null  float64
#  6   hla_high_res_8          22973 non-null  float64
#  7   tbi_status              28803 non-null  object
#  8   arrhythmia              26601 non-null  object
#  9   hla_low_res_6           25533 non-null  float64
#  10  graft_type              28803 non-null  object
#  11  vent_hist               28544 non-null  object
#  12  renal_issue             26888 non-null  object
#  13  pulm_severe             26668 non-null  object
#  14  prim_disease_hct        28803 non-null  object
#  15  hla_high_res_6          23519 non-null  float64
#  16  cmv_status              28169 non-null  object
#  17  hla_high_res_10         21639 non-null  float64
#  18  hla_match_dqb1_high     23604 non-null  float64
#  19  tce_imm_match           17669 non-null  object
#  20  hla_nmdp_6              24606 non-null  float64
#  21  hla_match_c_low         26003 non-null  float64
#  22  rituximab               26655 non-null  object
#  23  hla_match_drb1_low      26160 non-null  float64
#  24  hla_match_dqb1_low      24609 non-null  float64
#  25  prod_type               28803 non-null  object
#  26  cyto_score_detail       16878 non-null  object
#  27  conditioning_intensity  24012 non-null  object
#  28  ethnicity               28216 non-null  object
#  29  year_hct                28803 non-null  int64
#  30  obesity                 27043 non-null  object
#  31  mrd_hct                 12204 non-null  object
#  32  in_vivo_tcd             28578 non-null  object
#  33  tce_match               9805 non-null   object
#  34  hla_match_a_high        24502 non-null  float64
#  35  hepatic_severe          26932 non-null  object
#  36  donor_age               26993 non-null  float64
#  37  prior_tumor             27125 non-null  object
#  38  hla_match_b_low         26238 non-null  float64
#  39  peptic_ulcer            26384 non-null  object
#  40  age_at_hct              28803 non-null  float64
#  41  hla_match_a_low         26413 non-null  float64
#  42  gvhd_proph              28578 non-null  object
#  43  rheum_issue             26620 non-null  object
#  44  sex_match               28542 non-null  object
#  45  hla_match_b_high        24715 non-null  float64
#  46  race_group              28803 non-null  object
#  47  comorbidity_score       28326 non-null  float64
#  48  karnofsky_score         27933 non-null  float64
#  49  hepatic_mild            26886 non-null  object
#  50  tce_div_match           17406 non-null  object
#  51  donor_related           28645 non-null  object
#  52  melphalan_dose          27398 non-null  object
#  53  hla_low_res_8           25150 non-null  float64
#  54  cardiac                 26261 non-null  object
#  55  hla_match_drb1_high     25451 non-null  float64
#  56  pulm_moderate           26756 non-null  object
#  57  hla_low_res_10          23739 non-null  float64
#  58  efs                     28800 non-null  float64
#  59  efs_time                28800 non-null  float64
# dtypes: float64(23), int64(2), object(35)
# memory usage: 13.4+ MB

# %%
combined.dtypes
# Out:
# ID                          int64
# dri_score                  object
# psych_disturb              object
# cyto_score                 object
# diabetes                   object
# hla_match_c_high          float64
# hla_high_res_8            float64
# tbi_status                 object
# arrhythmia                 object
# hla_low_res_6             float64
# graft_type                 object
# vent_hist                  object
# renal_issue                object
# pulm_severe                object
# prim_disease_hct           object
# hla_high_res_6            float64
# cmv_status                 object
# hla_high_res_10           float64
# hla_match_dqb1_high       float64
# tce_imm_match              object
# hla_nmdp_6                float64
# hla_match_c_low           float64
# rituximab                  object
# hla_match_drb1_low        float64
# hla_match_dqb1_low        float64
# prod_type                  object
# cyto_score_detail          object
# conditioning_intensity     object
# ethnicity                  object
# year_hct                    int64
# obesity                    object
# mrd_hct                    object
# in_vivo_tcd                object
# tce_match                  object
# hla_match_a_high          float64
# hepatic_severe             object
# donor_age                 float64
# prior_tumor                object
# hla_match_b_low           float64
# peptic_ulcer               object
# age_at_hct                float64
# hla_match_a_low           float64
# gvhd_proph                 object
# rheum_issue                object
# sex_match                  object
# hla_match_b_high          float64
# race_group                 object
# comorbidity_score         float64
# karnofsky_score           float64
# hepatic_mild               object
# tce_div_match              object
# donor_related              object
# melphalan_dose             object
# hla_low_res_8             float64
# cardiac                    object
# hla_match_drb1_high       float64
# pulm_moderate              object
# hla_low_res_10            float64
# efs                       float64
# efs_time                  float64
# dtype: object

# %%
combined.columns
# Out:
# Index(['ID', 'dri_score', 'psych_disturb', 'cyto_score', 'diabetes',
#        'hla_match_c_high', 'hla_high_res_8', 'tbi_status', 'arrhythmia',
#        'hla_low_res_6', 'graft_type', 'vent_hist', 'renal_issue',
#        'pulm_severe', 'prim_disease_hct', 'hla_high_res_6', 'cmv_status',
#        'hla_high_res_10', 'hla_match_dqb1_high', 'tce_imm_match', 'hla_nmdp_6',
#        'hla_match_c_low', 'rituximab', 'hla_match_drb1_low',
#        'hla_match_dqb1_low', 'prod_type', 'cyto_score_detail',
#        'conditioning_intensity', 'ethnicity', 'year_hct', 'obesity', 'mrd_hct',
#        'in_vivo_tcd', 'tce_match', 'hla_match_a_high', 'hepatic_severe',
#        'donor_age', 'prior_tumor', 'hla_match_b_low', 'peptic_ulcer',
#        'age_at_hct', 'hla_match_a_low', 'gvhd_proph', 'rheum_issue',
#        'sex_match', 'hla_match_b_high', 'race_group', 'comorbidity_score',
#        'karnofsky_score', 'hepatic_mild', 'tce_div_match', 'donor_related',
#        'melphalan_dose', 'hla_low_res_8', 'cardiac', 'hla_match_drb1_high',
#        'pulm_moderate', 'hla_low_res_10', 'efs', 'efs_time'],
#       dtype='object')

# %%
combined.describe().T
# Out:
#                        count          mean          std       min         25%  \
# ID                   28803.0  14401.000000  8314.854238     0.000  7200.50000
# hla_match_c_high     24182.0      1.764536     0.431929     0.000     2.00000
# hla_high_res_8       22973.0      6.876899     1.564280     2.000     6.00000
# hla_low_res_6        25533.0      5.143422     1.207722     2.000     4.00000
# hla_high_res_6       23519.0      5.109316     1.214126     0.000     4.00000
# hla_high_res_10      21639.0      8.617358     1.905083     3.000     7.00000
# hla_match_dqb1_high  23604.0      1.736909     0.447668     0.000     1.00000
# hla_nmdp_6           24606.0      5.160449     1.203202     2.000     4.00000
# hla_match_c_low      26003.0      1.757836     0.435436     0.000     2.00000
# hla_match_drb1_low   26160.0      1.715329     0.451266     1.000     1.00000
# hla_match_dqb1_low   24609.0      1.773823     0.427112     0.000     2.00000
# year_hct             28803.0   2015.179356     3.154117  2008.000  2013.00000
# hla_match_a_high     24502.0      1.703779     0.462196     0.000     1.00000
# donor_age            26993.0     42.512694    15.252228    18.010    28.44700
# hla_match_b_low      26238.0      1.719948     0.454433     0.000     1.00000
# age_at_hct           28803.0     38.662178    21.147195     0.044    19.53900
# hla_match_a_low      26413.0      1.709121     0.458243     0.000     1.00000
# hla_match_b_high     24715.0      1.699656     0.465164     0.000     1.00000
# comorbidity_score    28326.0      1.702252     1.994403     0.000     0.00000
# karnofsky_score      27933.0     83.832743    11.028433    40.000    70.00000
# hla_low_res_8        25150.0      6.903579     1.564970     2.000     6.00000
# hla_match_drb1_high  25451.0      1.707163     0.461163     0.000     1.00000
# hla_low_res_10       23739.0      8.664855     1.882687     4.000     7.00000
# 0           0.00125        0.00125        0.00125         0.00125
# 1           0.00125        0.00125        0.00125         0.00125
# 2           0.00125        0.00125        0.00125         0.00125
#
#        hla_low_res_8  cardiac  hla_match_drb1_high  pulm_moderate  \
# 0            0.00125  0.00125              0.00125        0.00125
# 1            0.00125  0.00125              0.00125        0.00125
# 2            0.00125  0.00125              0.00125        0.00125
# 3            0.00125  0.00125              0.00125        0.00125
# 4            0.00125  0.00125              0.00125        0.00125
# ...              ...      ...                  ...            ...
# 28798        0.00125  0.00125              0.00125        0.00125
# 28799        0.00125  0.00125              0.00125        0.00125
# 0            0.00125  0.00125              0.00125        0.00125
# 1            0.00125  0.00125              0.00125        0.00125
# 2            0.00125  0.00125              0.00125        0.00125
#
#        hla_low_res_10      efs  efs_time
# 0             0.00125  0.00125   0.00125
# 1             0.00125  0.00125   0.00125
# 2             0.00125  0.00125   0.00125
# 3             0.00125  0.00125   0.00125
# 4             0.00125  0.00125   0.00125
# ...               ...      ...       ...
# 28798         0.00125  0.00125   0.00125
# 28799         0.00125  0.00125   0.00125
# 0             0.00125  0.00125   0.00125
# 1             0.00125  0.00125   0.00125
# 2             0.00125  0.00125   0.00125
#
# [28803 rows x 60 columns]

# %%
combined.shape
# Out:
# (28803, 60)

# %%
combined.skew
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# <bound method DataFrame.skew of           ID                       dri_score psych_disturb    cyto_score  \
# 0          0  N/A - non-malignant indication            No           NaN
# 1          1                    Intermediate            No  Intermediate
# 2          2  N/A - non-malignant indication            No           NaN
# 3          3                            High            No  Intermediate
# 4          4                            High            No           NaN
# ...      ...                             ...           ...           ...
# 28798  28798  N/A - non-malignant indication            No          Poor
# 28799  28799                 N/A - pediatric            No           NaN
# 0      28800  N/A - non-malignant indication            No           NaN
# 1      28801                    Intermediate            No  Intermediate
# 2      28802  N/A - non-malignant indication            No           NaN
#
#       diabetes  hla_match_c_high  hla_high_res_8          tbi_status  \
# 0           No               NaN             NaN              No TBI
# 1           No               2.0             8.0  TBI +- Other, >cGy
# 2           No               2.0             8.0              No TBI
# 3           No               2.0             8.0              No TBI
# 4           No               2.0             8.0              No TBI
# ...        ...               ...             ...                 ...
# 28798       No               1.0             4.0              No TBI
# 28799       No               2.0             8.0              No TBI
# 0           No               NaN             NaN              No TBI
# 1           No               2.0             8.0  TBI +- Other, >cGy
# 2           No               2.0             8.0              No TBI
#
#       arrhythmia  hla_low_res_6        graft_type vent_hist renal_issue  \
# 0             No            6.0       Bone marrow        No          No
# 1             No            6.0  Peripheral blood        No          No
# 2             No            6.0       Bone marrow        No          No
# 3             No            6.0       Bone marrow        No          No
# 4             No            6.0  Peripheral blood        No          No
# ...          ...            ...               ...       ...         ...
# 28798         No            3.0  Peripheral blood        No         NaN
# 28799         No            6.0       Bone marrow        No          No
# 0             No            6.0       Bone marrow        No          No
# 1             No            6.0  Peripheral blood        No          No
# 2             No            6.0       Bone marrow        No          No
#
#       pulm_severe prim_disease_hct  hla_high_res_6 cmv_status  \
# 0              No              IEA             6.0        +/+
# 1              No              AML             6.0        +/+
# 2              No              HIS             6.0        +/+
# 3              No              ALL             6.0        +/+
# 4              No              MPN             6.0        +/+
# ...           ...              ...             ...        ...
# 28798         NaN              IPA             3.0        +/+
# 28799          No              SAA             6.0        +/+
# 0              No              IEA             6.0        +/+
# 1              No              AML             6.0        +/+
# 2              No              HIS             6.0        +/+
#
#        hla_high_res_10  hla_match_dqb1_high tce_imm_match  hla_nmdp_6  \
# 0                  NaN                  2.0           NaN         6.0
# 1                 10.0                  2.0           P/P         6.0
# 2                 10.0                  2.0           P/P         6.0
# 3                 10.0                  2.0           P/P         6.0
# 4                 10.0                  2.0           NaN         5.0
# ...                ...                  ...           ...         ...
# 28798              5.0                  1.0           P/P         3.0
# 28799             10.0                  2.0           P/P         6.0
# 0                  NaN                  2.0           NaN         6.0
# 1                 10.0                  2.0           P/P         6.0
# 2                 10.0                  2.0           P/P         6.0
#
#        hla_match_c_low rituximab  hla_match_drb1_low  hla_match_dqb1_low  \
# 0                  2.0        No                 2.0                 2.0
# 1                  2.0        No                 2.0                 2.0
# 2                  2.0        No                 2.0                 2.0
# 3                  2.0        No                 2.0                 2.0
# 4                  2.0        No                 2.0                 2.0
# ...                ...       ...                 ...                 ...
# 28798              1.0        No                 1.0                 1.0
# 28799              2.0        No                 2.0                 2.0
# 0                  2.0        No                 2.0                 2.0
# 1                  2.0        No                 2.0                 2.0
# 2                  2.0        No                 2.0                 2.0
#
#       prod_type cyto_score_detail conditioning_intensity  \
# 0            BM               NaN                    NaN
# 1            PB      Intermediate                    MAC
# 2            BM               NaN                    NaN
# 3            BM      Intermediate                    MAC
# 4            PB               NaN                    MAC
# ...         ...               ...                    ...
# 28798        PB               NaN                    NMA
# 28799        BM               NaN                    NaN
# 0            BM               NaN                    NaN
# 1            PB      Intermediate                    MAC
# 2            BM               NaN                    NaN
#
#                     ethnicity  year_hct obesity   mrd_hct in_vivo_tcd  \
# 0      Not Hispanic or Latino      2016      No       NaN         Yes
# 1      Not Hispanic or Latino      2008      No  Positive          No
# 2      Not Hispanic or Latino      2019      No       NaN         Yes
# 3      Not Hispanic or Latino      2009      No  Positive          No
# 4          Hispanic or Latino      2018      No       NaN         Yes
# ...                       ...       ...     ...       ...         ...
# 28798  Not Hispanic or Latino      2018     NaN       NaN         Yes
# 28799  Not Hispanic or Latino      2018      No       NaN         Yes
# 0      Not Hispanic or Latino      2016      No       NaN         Yes
# 1      Not Hispanic or Latino      2008      No  Positive          No
# 2      Not Hispanic or Latino      2019      No       NaN         Yes
#
#         tce_match  hla_match_a_high hepatic_severe  donor_age prior_tumor  \
# 0             NaN               2.0             No        NaN          No
# 1      Permissive               2.0             No     72.290          No
# 2             NaN               2.0             No        NaN          No
# 3      Permissive               2.0             No     29.230          No
# 4             NaN               2.0             No     56.810          No
# ...           ...               ...            ...        ...         ...
# 28798         NaN               1.0             No     58.074         Yes
# 28799         NaN               2.0             No     30.571          No
# 0             NaN               2.0             No        NaN          No
# 1      Permissive               2.0             No     72.290          No
# 2             NaN               2.0             No        NaN          No
#
#        hla_match_b_low peptic_ulcer  age_at_hct  hla_match_a_low  \
# 0                  2.0           No       9.942              2.0
# 1                  2.0           No      43.705              2.0
# 2                  2.0           No      33.997              2.0
# 3                  2.0           No      43.245              2.0
# 4                  2.0           No      29.740              2.0
# ...                ...          ...         ...              ...
# 28798              1.0          NaN       0.044              1.0
# 28799              2.0           No       1.035              2.0
# 0                  2.0           No       9.942              2.0
# 1                  2.0           No      43.705              2.0
# 2                  2.0           No      33.997              2.0
#
#                        gvhd_proph rheum_issue sex_match  hla_match_b_high  \
# 0                         FKalone          No       M-F               2.0
# 1          Other GVHD Prophylaxis          No       F-F               2.0
# 2          Cyclophosphamide alone          No       F-M               2.0
# 3               FK+ MMF +- others          No       M-M               2.0
# 4             TDEPLETION +- other          No       M-F               2.0
# ...                           ...         ...       ...               ...
# 28798      Cyclophosphamide alone          No       M-M               1.0
# 28799  Cyclophosphamide +- others          No       M-M               2.0
# 0                         FKalone          No       M-F               2.0
# 1          Other GVHD Prophylaxis          No       F-F               2.0
# 2          Cyclophosphamide alone          No       F-M               2.0
#
#                              race_group  comorbidity_score  karnofsky_score  \
# 0                    More than one race                0.0             90.0
# 1                                 Asian                3.0             90.0
# 2                    More than one race                0.0             90.0
# 3                                 White                0.0             90.0
# 4      American Indian or Alaska Native                1.0             90.0
# ...                                 ...                ...              ...
# 28798         Black or African-American                1.0             90.0
# 28799         Black or African-American                2.0             90.0
# 0                    More than one race                0.0             90.0
# 1                                 Asian                3.0             90.0
# 2                    More than one race                0.0             90.0
#
#       hepatic_mild          tce_div_match donor_related      melphalan_dose  \
# 0               No                    NaN     Unrelated  N/A, Mel not given
# 1               No  Permissive mismatched       Related  N/A, Mel not given
# 2               No  Permissive mismatched       Related  N/A, Mel not given
# 3              Yes  Permissive mismatched     Unrelated  N/A, Mel not given
# 4               No  Permissive mismatched       Related                 MEL
# ...            ...                    ...           ...                 ...
# 28798           No  Permissive mismatched       Related                 MEL
# 28799           No  Permissive mismatched       Related                 MEL
# 0               No                    NaN     Unrelated  N/A, Mel not given
# 1               No  Permissive mismatched       Related  N/A, Mel not given
# 2               No  Permissive mismatched       Related  N/A, Mel not given
#
#        hla_low_res_8 cardiac  hla_match_drb1_high pulm_moderate  \
# 0                8.0      No                  2.0            No
# 1                8.0      No                  2.0           Yes
# 2                8.0      No                  2.0            No
# 3                8.0      No                  2.0            No
# 4                8.0      No                  2.0            No
# ...              ...     ...                  ...           ...
# 28798            4.0      No                  1.0            No
# 28799            8.0      No                  2.0           Yes
# 0                8.0      No                  2.0            No
# 1                8.0      No                  2.0           Yes
# 2                8.0      No                  2.0            No
#
#        hla_low_res_10  efs  efs_time
# 0                10.0  0.0    42.356
# 1                10.0  1.0     4.672
# 2                10.0  0.0    19.793
# 3                10.0  0.0   102.349
# 4                10.0  0.0    16.223
# ...               ...  ...       ...
# 28798             5.0  0.0    52.351
# 28799            10.0  0.0    25.158
# 0                10.0  NaN       NaN
# 1                10.0  NaN       NaN
# 2                10.0  NaN       NaN
#
# [28803 rows x 60 columns]>

# %%
sns.boxplot(combined)
# Out:
# <Axes: >

# %%
sns.barplot(combined)
# Out:
# <Axes: >

# %%
sns.kdeplot(combined)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: ylabel='Density'>

# %%
sns.scatterplot(combined)
# Out:
# <Axes: >
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.pairplot(combined)

# %%
sns.violinplot(combined)

# %%
sns.lineplot(combined)

# %%
cat_cols = combined.select_dtypes(include='object')

# %%
for i in cat_cols:
    ([combined[i].value_counts()])
    print(i) 
print(''*100)
# Out:
# dri_score
# psych_disturb
# cyto_score
# diabetes
# tbi_status
# arrhythmia
# graft_type
# vent_hist
# renal_issue
# pulm_severe
# prim_disease_hct
# cmv_status
# tce_imm_match
# rituximab
# prod_type
# cyto_score_detail
# conditioning_intensity
# ethnicity
# obesity
# mrd_hct
# in_vivo_tcd
# tce_match
# hepatic_severe
# prior_tumor
# peptic_ulcer
# gvhd_proph
# rheum_issue
# sex_match
# race_group
# hepatic_mild
# tce_div_match
# donor_related
# melphalan_dose
# cardiac
# pulm_moderate

# %%
num_cols = combined.select_dtypes(include='number')

# %%
for i in num_cols :
    ([combined[i].value_counts()])
    print(i) 
print(''*100)
# Out:
# ID
# hla_match_c_high
# hla_high_res_8
# hla_low_res_6
# hla_high_res_6
# hla_high_res_10
# hla_match_dqb1_high
# hla_nmdp_6
# hla_match_c_low
# hla_match_drb1_low
# hla_match_dqb1_low
# year_hct
# hla_match_a_high
# donor_age
# hla_match_b_low
# age_at_hct
# hla_match_a_low
# hla_match_b_high
# comorbidity_score
# karnofsky_score
# hla_low_res_8
# hla_match_drb1_high
# hla_low_res_10
# efs
# efs_time

# %%
x = i 
plt.figure(figsize=(12,10))
cat_cols = combined.select_dtypes(include='object')
for i in cat_cols :
    sns.scatterplot(data=combined)
    print('\n')
    plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
##x = i
#plt.figure(figszie=(5,10))
#num_cols = combined.select_dtypes(include='number')
#for i in num_cols:
 #   sns.kdeplot(data=combined)
  #  print('\n')
    plt.show() ##

# %%
plt.figire(figsize=(12,10))
sns.boxplot(data=combined,palette='mako');
plt.xticks(rotation=35);
plt.show()

# %%
sns.violinplot(data=combined) 
plt.xticks(rotation=40);
plt.show()

# %%
plt.figure(figsize=(12,15))
sns.scatterplot(data=combined,palette='mako');
plt.xticks(rotation=90);
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.heatmap(combined.corr(),annot=True,cmap='afmhot_r')
plt.show()
